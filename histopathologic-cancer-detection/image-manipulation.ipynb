# %%
from PIL import Image
import numpy as np

# %%
# Finding how to focus on 32 x 32 matrix 
im = Image.open('./cnn_train/Cancerous/0a0ce1220f56a48bf14615f80bc4c684244c909d.tif')
# Displaying the 96x96 pixel image
im
# Out:
# <PIL.TiffImagePlugin.TiffImageFile image mode=RGB size=96x96 at 0x116B6E390>

# %%
# Cropping the images size to a box of 32x32 pixels 
im_array = np.array(im.crop((32, 32, 64, 64)))
# Displaying the 32x32 pixel image
Image.fromarray(im_array)
# Out:
# <PIL.Image.Image image mode=RGB size=32x32 at 0x116C02750>
